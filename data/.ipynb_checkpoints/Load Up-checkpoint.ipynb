# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline
import requests
from bs4 import BeautifulSoup as Soup
import re

# %%
listings_url = "http://cdec.water.ca.gov/cgi-progs/staSearch?staid=&sensor_chk=on&sensor=15&dur=D&active=&lon1=&lon2=&lat1=&lat2=&elev1=-5&elev2=99000&nearby=&display=staid"

# %%
reservoir_listing = Soup(requests.get(listings_url).content)

# %%
rows = reservoir_listing.findAll('tr')

# %%
[row.find('td').a.text for row in rows if row.find('td')]
# Out:
# [u'ALM',
#  u'ANT',
#  u'APN',
#  u'AST',
#  u'ATN',
#  u'BAR',
#  u'BCL',
#  u'BDP',
#  u'BER',
#  u'BHC',
#  u'BIL',
#  u'BIO',
#  u'BIT',
#  u'BLB',
#  u'BMP',
#  u'BOC',
#  u'BQC',
#  u'BRD',
#  u'BRT',
#  u'BRV',
#  u'BTH',
#  u'BTV',
#  u'BUC',
#  u'BUL',
#  u'BUR',
#  u'BUX',
#  u'BWN',
#  u'BWS',
#  u'CAS',
#  u'CCH',
#  u'CFW',
#  u'CGS',
#  u'CHB',
#  u'CHV',
#  u'CHY',
#  u'CKL',
#  u'CLA',
#  u'CLE',
#  u'CLK',
#  u'CMB',
#  u'CMI',
#  u'CMN',
#  u'CNV',
#  u'COY',
#  u'CPL',
#  u'CRW',
#  u'CRY',
#  u'CSI',
#  u'CTG',
#  u'CUY',
#  u'CVE',
#  u'CYC',
#  u'CYL',
#  u'DAV',
#  u'DLV',
#  u'DMV',
#  u'DNL',
#  u'DNN',
#  u'DNP',
#  u'DON',
#  u'DRE',
#  u'DWN',
#  u'ECO',
#  u'EDN',
#  u'ELC',
#  u'ENB',
#  u'ENG',
#  u'ENR',
#  u'EPK',
#  u'EXC',
#  u'FLR',
#  u'FMD',
#  u'FOL',
#  u'FRD',
#  u'FRL',
#  u'FRM',
#  u'GBL',
#  u'GBR',
#  u'GDW',
#  u'GLK',
#  u'GLL',
#  u'GNT',
#  u'HDG',
#  u'HHL',
#  u'HHY',
#  u'HID',
#  u'HMT',
#  u'HNN',
#  u'HNS',
#  u'HNT',
#  u'HTH',
#  u'HVS',
#  u'HWE',
#  u'ICH',
#  u'INL',
#  u'INP',
#  u'INV',
#  u'IRC',
#  u'IRG',
#  u'ISB',
#  u'JCK',
#  u'JNC',
#  u'JNK',
#  u'JNN',
#  u'KES',
#  u'KLM',
#  u'KNT',
#  u'KRH',
#  u'LBS',
#  u'LEW',
#  u'LFY',
#  u'LGT',
#  u'LGV',
#  u'LNG',
#  u'LON',
#  u'LOT',
#  u'LPY',
#  u'LRA',
#  u'LSB',
#  u'LUS',
#  u'LVD',
#  u'LVQ',
#  u'LVY',
#  u'LWB',
#  u'LYS',
#  u'MAR',
#  u'MAT',
#  u'MCO',
#  u'MCR',
#  u'MCS',
#  u'MDO',
#  u'MEA',
#  u'MFF',
#  u'MHV',
#  u'MHW',
#  u'MIL',
#  u'MMR',
#  u'MMW',
#  u'MNC',
#  u'MOR',
#  u'MPD',
#  u'MPL',
#  u'MRR',
#  u'MRT',
#  u'NAT',
#  u'NCA',
#  u'NCM',
#  u'NHG',
#  u'NML',
#  u'ONF',
#  u'ORO',
#  u'OWN',
#  u'PAR',
#  u'PLL',
#  u'PNF',
#  u'PRA',
#  u'PRR',
#  u'PRS',
#  u'PRU',
#  u'PT6',
#  u'PT7',
#  u'PWL',
#  u'PYM',
#  u'QUL',
#  u'RBL',
#  u'RDN',
#  u'RLC',
#  u'RLF',
#  u'RLL',
#  u'RTD',
#  u'SAT',
#  u'SCC',
#  u'SCD',
#  u'SDB',
#  u'SFL',
#  u'SGB',
#  u'SGC',
#  u'SHA',
#  u'SHV',
#  u'SIV',
#  u'SJT',
#  u'SKN',
#  u'SLB',
#  u'SLC',
#  u'SLF',
#  u'SLJ',
#  u'SLK',
#  u'SLN',
#  u'SLS',
#  u'SLW',
#  u'SNL',
#  u'SNN',
#  u'SOL',
#  u'SPB',
#  u'SPC',
#  u'SPG',
#  u'SPM',
#  u'STD',
#  u'STG',
#  u'STP',
#  u'SVO',
#  u'SVT',
#  u'SW3',
#  u'SWB',
#  u'TAB',
#  u'TAE',
#  u'TAH',
#  u'TFR',
#  u'THD',
#  u'TLC',
#  u'TMT',
#  u'TNM',
#  u'TRM',
#  u'TUL',
#  u'TWT',
#  u'UNV',
#  u'USL',
#  u'VAR',
#  u'VIL',
#  u'VLP',
#  u'WHI',
#  u'WHR',
#  u'WRS',
#  u'WSN']
